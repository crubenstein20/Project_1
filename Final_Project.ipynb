# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime
from pprint import pprint

# %%
#pull data from csv files
#flights
CharlotteFlights_Data = pd.read_csv("Resources/CharlotteChart.csv")
LAXFlights_Data = pd.read_csv("Resources/LAXchart.csv")
LittleRockchart_Data = pd.read_csv("Resources/LittleRockchart.csv")
CommericalFlights_Data = pd.read_csv("Resources/number-of-commercial-fli.csv")
TotalFlights_Data = pd.read_csv("Resources/total-number-of-flights.csv")
#covid-19
AllStatesHistorical_Data = pd.read_csv("Resources/HistoricalStateData.csv")

# %%
#merging flight data
merge_df=pd.merge(CharlotteFlights_Data,LAXFlights_Data,on="DateTime")
merge_df
# Out:
#    DateTime  Scheduled flights_x  Tracked flights_x  Scheduled flights_y  \
# 0   3/21/20                  770                678                  887
# 1   3/22/20                  794                680                  887
# 2   3/23/20                  802                537                  887
# 3   3/24/20                  791                447                  887
# 4   3/25/20                  774                362                  887
# 5   3/26/20                  790                400                  887
# 6   3/27/20                  789                361                  887
# 7   3/28/20                  748                349                  887
# 8   3/29/20                  784                366                  887
# 9   3/30/20                  787                340                  887
# 10  3/31/20                  772                326                  887
# 11   4/1/20                  758                376                  887
# 12   4/2/20                  772                370                  887
# 13   4/3/20                  776                458                  887
# 14   4/4/20                  738                360                  887
# 15   4/5/20                  762                370                  887
# 16   4/6/20                  757                381                  887
# 17   4/7/20                  696                311                  887
# 18   4/8/20                  677                316                  887
# 19   4/9/20                  687                339                  887
# 20  4/10/20                  673                344                  887
# 21  4/11/20                  626                298                  887
# 22  4/12/20                  651                317                  887
# 23  4/13/20                  598                359                  887
# 24  4/14/20                  598                337                  887
# 25  4/15/20                  622                311                  887
# 26  4/16/20                  636                286                  887
# 27  4/17/20                  647                307                  887
# 28  4/18/20                  568                249                  887
# 29  4/19/20                  583                267                  887
#
#     Tracked flights_y
# 0                 672
# 1                 672
# 2                 672
# 3                 672
# 4                 672
# 5                 672
# 6                 672
# 7                 672
# 8                 672
# 9                 672
# 10                672
# 11                672
# 12                672
# 13                672
# 14                672
# 15                672
# 16                672
# 17                672
# 18                672
# 19                672
# 20                672
# 21                672
# 22                672
# 23                672
# 24                672
# 25                672
# 26                672
# 27                672
# 28                672
# 29                672

# %%
merge_df1=pd.merge(merge_df,LittleRockchart_Data,on="DateTime")
merge_df1.head()
# Out:
#   DateTime  Scheduled flights_x  Tracked flights_x  Scheduled flights_y  \
# 0  3/21/20                  770                678                  887
# 1  3/22/20                  794                680                  887
# 2  3/23/20                  802                537                  887
# 3  3/24/20                  791                447                  887
# 4  3/25/20                  774                362                  887
#
#    Tracked flights_y  Scheduled flights  Tracked flights
# 0                672                 58               46
# 1                672                 49               34
# 2                672                 53               35
# 3                672                 58               37
# 4                672                 56               38

# %%
merge_df1.rename(columns={"Scheduled flights_x" : "Charlotte Scheduled Flights","Tracked flights_x":"Charlotte Tracked Flights","Scheduled flights_y":"LA Scheduled Flights","Tracked flights_y":"LA Tracked Flights","Scheduled flights" :"Arkansas_Scheduled flights", "Tracked flights":"Arkansas Tracked Flights"})
# Out:
#    DateTime  Charlotte Scheduled Flights  Charlotte Tracked Flights  \
# 0   3/21/20                          770                        678
# 1   3/22/20                          794                        680
# 2   3/23/20                          802                        537
# 3   3/24/20                          791                        447
# 4   3/25/20                          774                        362
# 5   3/26/20                          790                        400
# 6   3/27/20                          789                        361
# 7   3/28/20                          748                        349
# 8   3/29/20                          784                        366
# 9   3/30/20                          787                        340
# 10  3/31/20                          772                        326
# 11   4/1/20                          758                        376
# 12   4/2/20                          772                        370
# 13   4/3/20                          776                        458
# 14   4/4/20                          738                        360
# 15   4/5/20                          762                        370
# 16   4/6/20                          757                        381
# 17   4/7/20                          696                        311
# 18   4/8/20                          677                        316
# 19   4/9/20                          687                        339
# 20  4/10/20                          673                        344
# 21  4/11/20                          626                        298
# 22  4/12/20                          651                        317
# 23  4/13/20                          598                        359
# 24  4/14/20                          598                        337
# 25  4/15/20                          622                        311
# 26  4/16/20                          636                        286
# 27  4/17/20                          647                        307
# 28  4/18/20                          568                        249
# 29  4/19/20                          583                        267
#
#     LA Scheduled Flights  LA Tracked Flights  Arkansas_Scheduled flights  \
# 0                    887                 672                          58
# 1                    887                 672                          49
# 2                    887                 672                          53
# 3                    887                 672                          58
# 4                    887                 672                          56
# 5                    887                 672                          58
# 6                    887                 672                          59
# 7                    887                 672                          44
# 8                    887                 672                          45
# 9                    887                 672                          54
# 10                   887                 672                          58
# 11                   887                 672                          55
# 12                   887                 672                          59
# 13                   887                 672                          51
# 14                   887                 672                          41
# 15                   887                 672                          41
# 16                   887                 672                          44
# 17                   887                 672                          40
# 18                   887                 672                          47
# 19                   887                 672                          45
# 20                   887                 672                          38
# 21                   887                 672                          32
# 22                   887                 672                          27
# 23                   887                 672                          38
# 24                   887                 672                          39
# 25                   887                 672                          36
# 26                   887                 672                          43
# 27                   887                 672                          44
# 28                   887                 672                          32
# 29                   887                 672                          31
#
#     Arkansas Tracked Flights
# 0                         46
# 1                         34
# 2                         35
# 3                         37
# 4                         38
# 5                         34
# 6                         33
# 7                         25
# 8                         19
# 9                         24
# 10                        31
# 11                        32
# 12                        37
# 13                        31
# 14                        25
# 15                        25
# 16                        25
# 17                        25
# 18                        30
# 19                        24
# 20                        25
# 21                        19
# 22                        12
# 23                        22
# 24                        25
# 25                        23
# 26                        32
# 27                        28
# 28                        19
# 29                        18
